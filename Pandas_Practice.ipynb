# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/rahulbanerjee/Rahul/iNeurone-docs/player-data/Player.csv',)

# %%
df[df['Country'] == 'India']['Player_Name'].min()
# Out:
# 'A Ashish Reddy'

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df.dtypes
# Out:
# a     object
# b     object
# c     object
# d     object
# e     object
# f     object
# g     object
# h    float64
# dtype: object

# %%
df.describe()
# Out:
#                h
# count  12.000000
# mean    6.500000
# std     3.605551
# min     1.000000
# 25%     3.750000
# 50%     6.500000
# 75%     9.250000
# max    12.000000

# %%
df.dtypes
# Out:
# Player_Id          int64
# Player_Name       object
# DOB               object
# Batting_Hand      object
# Bowling_Skill     object
# Country           object
# Is_Umpire          int64
# Unnamed: 7       float64
# dtype: object

# %%
df1 = pd.read_csv('/Users/rahulbanerjee/Rahul/iNeurone-docs/player-data/Player.csv',usecols=['Player_Name','Batting_Hand'])

# %%
df['Player_Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 518    519
# 519    520
# 520    521
# 521    523
# 522    524
# Name: Player_Id, Length: 523, dtype: int64

# %%
type(df['Player_Id'])
# Out:
# pandas.core.series.Series

# %%
df2 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
for i in range(len(df2)):
    print("Start---------")
    print(df2[i])
# Out:
# Start---------
#        Season   Age                                   Team  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
import json
s = """{
"name" :"sudh",
"phone_no" : 45454545,
"comp":["iNeuron", "EY" , "unilver" , "verizon" , "deloitte" , "wipro"]
}
"""
s3 = json.loads(s)
# Out:
# {'name': 'sudh',
#  'phone_no': 45454545,
#  'comp': ['iNeuron', 'EY', 'unilver', 'verizon', 'deloitte', 'wipro']}

# %%
df3 = pd.DataFrame(s3,columns=['name','comp'])

# %%
df3
# Out:
#    name      comp
# 0  sudh   iNeuron
# 1  sudh        EY
# 2  sudh   unilver
# 3  sudh   verizon
# 4  sudh  deloitte
# 5  sudh     wipro

# %%
df4 = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
df5 = pd.DataFrame.from_records(df4['user'])[['id','node_id']]

# %%
df5
# Out:
#           id               node_id
# 0    5811028  MDQ6VXNlcjU4MTEwMjg=
# 1    5811028  MDQ6VXNlcjU4MTEwMjg=
# 2    1199593  MDQ6VXNlcjExOTk1OTM=
# 3   47838927  MDQ6VXNlcjQ3ODM4OTI3
# 4    6618166  MDQ6VXNlcjY2MTgxNjY=
# 5   54398132  MDQ6VXNlcjU0Mzk4MTMy
# 6   33491632  MDQ6VXNlcjMzNDkxNjMy
# 7    1020496  MDQ6VXNlcjEwMjA0OTY=
# 8    6302028  MDQ6VXNlcjYzMDIwMjg=
# 9   24256554  MDQ6VXNlcjI0MjU2NTU0
# 10  13602468  MDQ6VXNlcjEzNjAyNDY4
# 11  18103560  MDQ6VXNlcjE4MTAzNTYw
# 12  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 13  10884874  MDQ6VXNlcjEwODg0ODc0
# 14  37011898  MDQ6VXNlcjM3MDExODk4
# 15   8078968  MDQ6VXNlcjgwNzg5Njg=
# 16   8078968  MDQ6VXNlcjgwNzg5Njg=
# 17  23101198  MDQ6VXNlcjIzMTAxMTk4
# 18   1020496  MDQ6VXNlcjEwMjA0OTY=
# 19   1020496  MDQ6VXNlcjEwMjA0OTY=
# 20  42706631  MDQ6VXNlcjQyNzA2NjMx
# 21   8078968  MDQ6VXNlcjgwNzg5Njg=
# 22   1020496  MDQ6VXNlcjEwMjA0OTY=
# 23  57575138  MDQ6VXNlcjU3NTc1MTM4
# 24  24256554  MDQ6VXNlcjI0MjU2NTU0
# 25   1203825  MDQ6VXNlcjEyMDM4MjU=
# ...
